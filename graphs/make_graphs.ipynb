# %%
orig_loss_bon = [.244, .304, .346, .364, .4, .396, .378, .354]

orig_loss_wbon =  [.244, .304, .36, .41, .484, .526, .554, .592]

truncated_loss_bon = [.253, .307,.358, .392, .398, .408, .4, .345]

truncated_loss_wbon  = [.253, .307,.377, .446, .499, .541, .583, .592]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 4, 8, 16, 32, 64, 128]

plt.plot(x, orig_loss_wbon, color='red', linestyle='-', label='Original Weighted Best-of-n')
plt.plot(x, orig_loss_bon, color='red', linestyle='--', label='Original Best-of-n')
plt.plot(x, truncated_loss_wbon, color='blue', linestyle='-', label='Truncated Weighted Best-of-n')
plt.plot(x, truncated_loss_bon, color='blue', linestyle='--', label='Truncated Best-of-n')

plt.xlabel('n')
plt.ylabel('Accuracy')
plt.xscale('log', base=2)
plt.xticks(x, x)
plt.legend()
plt.title('Math500 Accuracy vs Number of completions')

plt.savefig('loss_vs_n.pdf')
plt.show()
